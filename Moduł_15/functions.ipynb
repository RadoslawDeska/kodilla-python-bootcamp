# %% [markdown]
# używamy słowa def

# %%
def add(a,b):
    return a+b

# %% [markdown]
# wywołujemy funkcję używając nawiasów okrągłych, po przecinku podając składniki sumy

# %%
add(1,1)
# Out:
# 2
